# %%
# Import libraries 

import pandas as pd 
import matplotlib.pyplot as plt 
import requests 

import nltk 
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter 
import re, os

# %%
# Calling API 

API_key = '16dc3ec0156243cc9ca1fa7dd283b6db' 
query = 'AI'

# %%
url = f'https://newsapi.org/v2/everything?q={query}&from=2025-05-04&to=2025-06-03&language=en&apiKey={API_key}'

response = requests.get(url)
articles = response.json()['articles']

# %%
# Collect articles and make them a list 

texts = [a['title'] + ' ' + (a['description'] or '') for a in articles]

# %%
# Function to clean the news articles  

def clean_text(texts): 
    texts = re.sub(r'[^a-zA-Z ]', '', texts) 
    return texts.lower()

# %%
# Function to remove plural 

def basic_lemmatize(word):
    if word.endswith('s') and not word.endswith('ss'):
        return word[:-1]
    return word

# %%
# Make the list of articles after cleaning 

cleaned = [clean_text(t) for t in texts]

# %%
# Combine all the cleaned words  

all_words = " ".join(cleaned).split()

# %%
print(all_words)
# Out:
# ['google', 'is', 'stuffing', 'even', 'more', 'ads', 'into', 'its', 'ai', 'results', 'googles', 'ai', 'search', 'results', 'are', 'about', 'to', 'get', 'even', 'more', 'ads', 'on', 'may', 'st', 'the', 'company', 'announced', 'that', 'its', 'going', 'to', 'start', 'testing', 'ads', 'in', 'ai', 'mode', 'the', 'new', 'aipowered', 'search', 'feature', 'that', 'just', 'rolled', 'out', 'to', 'everyone', 'in', 'the', 'us', 'ai', 'mode', 'is', 'the', 'new', 'tab', 'in', 'google', 'searc', 'you', 'can', 'now', 'try', 'interactive', 'ai', 'worlds', 'backed', 'by', 'pixars', 'cofounder', 'ai', 'companies', 'have', 'recently', 'been', 'experimenting', 'with', 'interactive', 'aigenerated', 'worlds', 'theres', 'an', 'aigenerated', 'version', 'of', 'quake', 'an', 'aigenerated', 'minecraft', 'google', 'deepmind', 'is', 'also', 'building', 'a', 'team', 'to', 'develop', 'models', 'that', 'simulate', 'the', 'world', 'now', 'an', 'ai', 'startup', 'b', 'microsofts', 'ai', 'security', 'chief', 'accidentally', 'reveals', 'walmarts', 'ai', 'plans', 'after', 'protest', 'microsofts', 'head', 'of', 'security', 'for', 'ai', 'neta', 'haiby', 'accidentally', 'revealed', 'confidential', 'messages', 'about', 'walmarts', 'use', 'of', 'microsofts', 'ai', 'tools', 'during', 'a', 'build', 'talk', 'that', 'was', 'disrupted', 'by', 'protesters', 'the', 'build', 'livestream', 'was', 'muted', 'and', 'the', 'camera', 'pointed', 'down', 'but', 'the', 'the', 'middle', 'east', 'has', 'entered', 'the', 'ai', 'group', 'chat', 'the', 'uae', 'and', 'saudi', 'arabia', 'are', 'investing', 'billions', 'in', 'us', 'ai', 'infrastructure', 'the', 'deals', 'could', 'help', 'the', 'us', 'in', 'the', 'ai', 'race', 'against', 'china', 'how', 'peter', 'thiels', 'relationship', 'with', 'eliezer', 'yudkowsky', 'launched', 'the', 'ai', 'revolution', 'the', 'ai', 'doomer', 'and', 'the', 'ai', 'boomer', 'both', 'created', 'each', 'others', 'monsters', 'an', 'excerpt', 'from', 'the', 'optimist', 'sam', 'altman', 'openai', 'and', 'the', 'race', 'to', 'invent', 'the', 'future', 'the', 'ai', 'wearables', 'are', 'always', 'listening', 'the', 'ai', 'recorder', 'premise', 'is', 'an', 'enticing', 'one', 'you', 'wear', 'this', 'tiny', 'microphone', 'around', 'your', 'neck', 'on', 'your', 'wrist', 'or', 'pinned', 'to', 'your', 'sweater', 'and', 'it', 'records', 'everything', 'your', 'recorder', 'can', 'tell', 'you', 'all', 'the', 'things', 'you', 'promised', 'to', 'do', 'and', 'immediately', 'forgot', 'remind', 'you', 'wh', 'openai', 'and', 'jony', 'ives', 'ai', 'supergadget', 'heres', 'what', 'we', 'know', 'its', 'probably', 'not', 'smart', 'glasses', 'beyond', 'that', 'we', 'dont', 'know', 'much', 'about', 'what', 'jony', 'ive', 'and', 'openai', 'are', 'building', 'through', 'their', 'newly', 'combined', 'company', 'io', 'except', 'that', 'its', 'some', 'kind', 'of', 'ai', 'supergadget', 'but', 'after', 'a', 'couple', 'of', 'years', 'of', 'watching', 't', 'gmails', 'ai', 'summaries', 'now', 'appear', 'automatically', 'google', 'workspace', 'users', 'are', 'going', 'to', 'see', 'a', 'lot', 'more', 'of', 'geminis', 'efforts', 'to', 'summarize', 'their', 'emails', 'gmail', 'now', 'creates', 'summaries', 'automatically', 'for', 'complex', 'threads', 'and', 'theyll', 'appear', 'above', 'the', 'emails', 'themselves', 'aipowered', 'summaries', 'of', 'emails', 'have', 'been', 'found', 'in', 'tech', 'ceos', 'are', 'using', 'ai', 'to', 'replace', 'themselves', 'tech', 'company', 'ceos', 'arent', 'just', 'making', 'their', 'companies', 'aifirst', 'this', 'week', 'theyre', 'using', 'ai', 'avatars', 'to', 'replace', 'themselves', 'in', 'earnings', 'calls', 'buy', 'now', 'pay', 'later', 'company', 'klarna', 'featured', 'the', 'ai', 'version', 'of', 'ceo', 'and', 'cofounder', 'sebastian', 'siemiatkowski', 'in', 'an', 'second', 'google', 'photos', 'adds', 'pixelexclusive', 'ai', 'features', 'to', 'redesigned', 'editor', 'google', 'photos', 'is', 'being', 'overhauled', 'with', 'more', 'ai', 'features', 'that', 'hel ...

# %%
nltk.download('stopwords', download_dir=r"C:\Users\lg2021\AppData\Roaming\nltk_data")
#nltk.download('wordnet', download_dir=r"C:\Users\lg2021\AppData\Roaming\nltk_data")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lg2021\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english')[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
# Create STOPWORDS 

nltk.data.path.append(r'C:\Users\lg2021\AppData\Roaming\nltk_data') 

stopwords = set(stopwords.words('english'))

custom_stopwords = {"will", "users", "announced", "your", "about", 'also', 'one'}
all_stopwords = stopwords.union(custom_stopwords)

# %%
# List of words that exclude stopwords 

filtered = [w for w in all_words if w not in all_stopwords and len(w) > 3]

# List of words that exclude lemmatizer 

final_word  = [basic_lemmatize(w) for w in filtered]

# %%
# Count the frequency of words that are more than 3 letters 

word_freq = Counter([w for w in filtered if len(w) > 3])

# %%
print(word_freq.most_common(10))
# Out:
# [('google', 48), ('googles', 16), ('gemini', 16), ('company', 13), ('search', 12), ('android', 12), ('openai', 11), ('features', 11), ('microsofts', 10), ('could', 10)]

# %%
# Visualise word count 

wc = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq) 

plt.figure(figsize=(10,6)) 

plt.imshow(wc, interpolation='bilinear')
plt.axis("off")

plt.show()
